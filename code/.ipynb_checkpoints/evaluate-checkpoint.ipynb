# %%
from evaluate import *

test_x_file = '/home/nesa320/huizhong/deepfm/dataset/test/test_x.npy'
test_y_file = '/home/nesa320/huizhong/deepfm/dataset/test/test_y.npy'
log_path = '/home/nesa320/huizhong/deepfm/log/deepfm_1000w_622.txt'
test_column = 'C20'
# Out:
# Failed to start the Kernel.
#
# Jupyter 笔记本启动失败。
#
# Unknown (FileSystemError) (FileSystemError): Error: ENOSPC: no space left on device, mkdir '/tmp/97b2573f-4189-4c5f-b83f-d336bd5c36c1'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
xy , xy_data , feat_value = get_test_data(test_x_file,test_y_file,test_column,log_path)

# %%
model_origin_path = '/home/nesa320/huizhong/deepfm/save/deepfm-v1000-622.ckpt'
sample_num = 1000 
feature_columns = getFeature(sample_num)

model = get_model(model_origin_path,feature_columns)
get_origin_auc_result(xy,xy_data,model,feat_value,log_path)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 39)]         0
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice (Tens [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_1 (Te [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_2 (Te [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_3 (Te [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_4 (Te [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_5 (Te [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_6 (Te [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_7 (Te [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_8 (Te [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_9 (Te [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_10 (T [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_11 (T [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_12 (T [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_13 (T [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_14 (T [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_15 (T [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_16 (T [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_17 (T [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_18 (T [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_19 (T [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_20 (T [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_21 (T [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_22 (T [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_23 (T [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_24 (T [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_25 (T [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_26 (T [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_27 (T [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_28 (T [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_29 (T [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_30 (T [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_31 (T [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_32 (T [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_33 (T [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_34 (T [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_35 (T [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_36 (T [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_37 (T [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_38 (T [(None,)]            0           input_1[0][0]
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 8)            11168       tf_op_layer_strided_slice[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 8)            4424        tf_op_layer_strided_slice_1[0][0]
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 8)            20752248    tf_op_layer_strided_slice_2[0][0]
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 8)            5587752     tf_op_layer_strided_slice_3[0][0]
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 8)            2320        tf_op_layer_strided_slice_4[0][0]
# __________________________________________________________________________________________________
# embedding_5 (Embedding)         (None, 8)            184         tf_op_layer_strided_slice_5[0][0]
# __________________________________________________________________________________________________
# embedding_6 (Embedding)         (None, 8)            96384       tf_op_layer_strided_slice_6[0][0]
# __________________________________________________________________________________________________
# embedding_7 (Embedding)         (None, 8)            4864        tf_op_layer_strided_slice_7[0][0]
# __________________________________________________________________________________________________
# embedding_8 (Embedding)         (None, 8)            24          tf_op_layer_strided_slice_8[0][0]
# __________________________________________________________________________________________________
# embedding_9 (Embedding)         (None, 8)            521248      tf_op_layer_strided_slice_9[0][0]
# __________________________________________________________________________________________________
# embedding_10 (Embedding)        (None, 8)            42472       tf_op_layer_strided_slice_10[0][0
# __________________________________________________________________________________________________
# embedding_11 (Embedding)        (None, 8)            17492072    tf_op_layer_strided_slice_11[0][0
# __________________________________________________________________________________________________
# embedding_12 (Embedding)        (None, 8)            25024       tf_op_layer_strided_slice_12[0][0
# __________________________________________________________________________________________________
# embedding_13 (Embedding)        (None, 8)            208         tf_op_layer_strided_slice_13[0][0
# __________________________________________________________________________________________________
# embedding_14 (Embedding)        (None, 8)            102000      tf_op_layer_strided_slice_14[0][0
# __________________________________________________________________________________________________
# embedding_15 (Embedding)        (None, 8)            12298584    tf_op_layer_strided_slice_15[0][0
# __________________________________________________________________________________________________
# embedding_16 (Embedding)        (None, 8)            80          tf_op_layer_strided_slice_16[0][0
# __________________________________________________________________________________________________
# embedding_17 (Embedding)        (None, 8)            40016       tf_op_layer_strided_slice_17[0][0
# __________________________________________________________________________________________________
# embedding_18 (Embedding)        (None, 8)            16944       tf_op_layer_strided_slice_18[0][0
# __________________________________________________________________________________________________
# embedding_19 (Embedding)        (None, 8)            32          tf_op_layer_strided_slice_19[0][0
# __________________________________________________________________________________________________
# embedding_20 (Embedding)        (None, 8)            15218616    tf_op_layer_strided_slice_20[0][0
# __________________________________________________________________________________________________
# embedding_21 (Embedding)        (None, 8)            136         tf_op_layer_strided_slice_21[0][0
# __________________________________________________________________________________________________
# embedding_22 (Embedding)        (None, 8)            120         tf_op_layer_strided_slice_22[0][0
# __________________________________________________________________________________________________
# embedding_23 (Embedding)        (None, 8)            1086312     tf_op_layer_strided_slice_23[0][0
# __________________________________________________________________________________________________
# embedding_24 (Embedding)        (None, 8)            752         tf_op_layer_strided_slice_24[0][0
# __________________________________________________________________________________________________
# embedding_25 (Embedding)        (None, 8)            674440      tf_op_layer_strided_slice_25[0][0
# __________________________________________________________________________________________________
# embedding_26 (Embedding)        (None, 8)            800         tf_op_layer_strided_slice_26[0][0
# __________________________________________________________________________________________________
# embedding_27 (Embedding)        (None, 8)            800         tf_op_layer_strided_slice_27[0][0
# __________________________________________________________________________________________________
# embedding_28 (Embedding)        (None, 8)            800         tf_op_layer_strided_slice_28[0][0
# __________________________________________________________________________________________________
# embedding_29 (Embedding)        (None, 8)            800         tf_op_layer_strided_slice_29[0][0
# __________________________________________________________________________________________________
# embedding_30 (Embedding)        (None, 8)            800         tf_op_layer_strided_slice_30[0][0
# __________________________________________________________________________________________________
# embedding_31 (Embedding)        (None, 8)            800         tf_op_layer_strided_slice_31[0][0
# __________________________________________________________________________________________________
# embedding_32 (Embedding)        (None, 8)            800         tf_op_layer_strided_slice_32[0][0
# __________________________________________________________________________________________________
# embedding_33 (Embedding)        (None, 8)            800         tf_op_layer_strided_slice_33[0][0
# __________________________________________________________________________________________________
# embedding_34 (Embedding)        (None, 8)            800         tf_op_layer_strided_slice_34[0][0
# __________________________________________________________________________________________________
# embedding_35 (Embedding)        (None, 8)            800         tf_op_layer_strided_slice_35[0][0
# __________________________________________________________________________________________________
# embedding_36 (Embedding)        (None, 8)            800         tf_op_layer_strided_slice_36[0][0
# __________________________________________________________________________________________________
# embedding_37 (Embedding)        (None, 8)            800         tf_op_layer_strided_slice_37[0][0
# __________________________________________________________________________________________________
# embedding_38 (Embedding)        (None, 8)            800         tf_op_layer_strided_slice_38[0][0
# __________________________________________________________________________________________________
# tf_op_layer_concat (TensorFlowO [(None, 312)]        0           embedding[0][0]
#                                                                  embedding_1[0][0]
#                                                                  embedding_2[0][0]
#                                                                  embedding_3[0][0]
#                                                                  embedding_4[0][0]
#                                                                  embedding_5[0][0]
#                                                                  embedding_6[0][0]
#                                                                  embedding_7[0][0]
#                                                                  embedding_8[0][0]
#                                                                  embedding_9[0][0]
#                                                                  embedding_10[0][0]
#                                                                  embedding_11[0][0]
#                                                                  embedding_12[0][0]
#                                                                  embedding_13[0][0]
#                                                                  embedding_14[0][0]
#                                                                  embedding_15[0][0]
#                                                                  embedding_16[0][0]
#                                                                  embedding_17[0][0]
#                                                                  embedding_18[0][0]
#                                                                  embedding_19[0][0]
#                                                                  embedding_20[0][0]
#                                                                  embedding_21[0][0]
#                                                                  embedding_22[0][0]
#                                                                  embedding_23[0][0]
#                                                                  embedding_24[0][0]
#                                                                  embedding_25[0][0]
#                                                                  embedding_26[0][0]
#                                                                  embedding_27[0][0]
#                                                                  embedding_28[0][0]
#                                                                  embedding_29[0][0]
#                                                                  embedding_30[0][0]
#                                                                  embedding_31[0][0]
#                                                                  embedding_32[0][0]
#                                                                  embedding_33[0][0]
#                                                                  embedding_34[0][0]
#                                                                  embedding_35[0][0]
#                                                                  embedding_36[0][0]
#                                                                  embedding_37[0][0]
#                                                                  embedding_38[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape (TensorFlow [(None, 39, 8)]      0           tf_op_layer_concat[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2 (TensorFlowOp [(None, 39)]         0           input_1[0][0]
# __________________________________________________________________________________________________
# dnn (DNN)                       (None, 64)           121280      tf_op_layer_concat[0][0]
# __________________________________________________________________________________________________
# fm (FM)                         (None, 1)            9248603     tf_op_layer_Reshape[0][0]
#                                                                  tf_op_layer_AddV2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            65          dnn[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Add (TensorFlowOpLa [(None, 1)]          0           fm[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sigmoid (TensorFlow [(None, 1)]          0           tf_op_layer_Add[0][0]
# ==================================================================================================
# Total params: 83,358,772
# Trainable params: 83,358,772
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 489/489 [==============================] - 46s 95ms/step - loss: 0.5737 - auc: 0.7461
# 438/438 [==============================] - 41s 95ms/step - loss: 0.5941 - auc: 0.7393
# 51/51 [==============================] - 5s 90ms/step - loss: 0.3971 - auc: 0.7417
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2881 - auc: 0.8008

# %%
model_save_path = '/home/nesa320/huizhong/deepfm/save_tune/'
version = 200
model_name = 'deepfm'
model_list = get_group_model(model_save_path,feat_value,feature_columns,version,test_column,model_name)

for i in range(len(feat_value)):
    print('')
    x_data, y_data = xy_data
    get_auc(x_data[i],y_data[i],model_list[i],feat_value[i],log_path)
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 39)]         0
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_156 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_157 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_158 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_159 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_160 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_161 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_162 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_163 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_164 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_165 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_166 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_167 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_168 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_169 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_170 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_171 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_172 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_173 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_174 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_175 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_176 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_177 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_178 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_179 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_180 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_181 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_182 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_183 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_184 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_185 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_186 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_187 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_188 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_189 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_190 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_191 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_192 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_193 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_194 ( [(None,)]            0           input_5[0][0]
# __________________________________________________________________________________________________
# embedding_156 (Embedding)       (None, 8)            11168       tf_op_layer_strided_slice_156[0][
# __________________________________________________________________________________________________
# embedding_157 (Embedding)       (None, 8)            4424        tf_op_layer_strided_slice_157[0][
# __________________________________________________________________________________________________
# embedding_158 (Embedding)       (None, 8)            20752248    tf_op_layer_strided_slice_158[0][
# __________________________________________________________________________________________________
# embedding_159 (Embedding)       (None, 8)            5587752     tf_op_layer_strided_slice_159[0][
# __________________________________________________________________________________________________
# embedding_160 (Embedding)       (None, 8)            2320        tf_op_layer_strided_slice_160[0][
# __________________________________________________________________________________________________
# embedding_161 (Embedding)       (None, 8)            184         tf_op_layer_strided_slice_161[0][
# __________________________________________________________________________________________________
# embedding_162 (Embedding)       (None, 8)            96384       tf_op_layer_strided_slice_162[0][
# __________________________________________________________________________________________________
# embedding_163 (Embedding)       (None, 8)            4864        tf_op_layer_strided_slice_163[0][
# __________________________________________________________________________________________________
# embedding_164 (Embedding)       (None, 8)            24          tf_op_layer_strided_slice_164[0][
# __________________________________________________________________________________________________
# embedding_165 (Embedding)       (None, 8)            521248      tf_op_layer_strided_slice_165[0][
# __________________________________________________________________________________________________
# embedding_166 (Embedding)       (None, 8)            42472       tf_op_layer_strided_slice_166[0][
# __________________________________________________________________________________________________
# embedding_167 (Embedding)       (None, 8)            17492072    tf_op_layer_strided_slice_167[0][
# __________________________________________________________________________________________________
# embedding_168 (Embedding)       (None, 8)            25024       tf_op_layer_strided_slice_168[0][
# __________________________________________________________________________________________________
# embedding_169 (Embedding)       (None, 8)            208         tf_op_layer_strided_slice_169[0][
# __________________________________________________________________________________________________
# embedding_170 (Embedding)       (None, 8)            102000      tf_op_layer_strided_slice_170[0][
# __________________________________________________________________________________________________
# embedding_171 (Embedding)       (None, 8)            12298584    tf_op_layer_strided_slice_171[0][
# __________________________________________________________________________________________________
# embedding_172 (Embedding)       (None, 8)            80          tf_op_layer_strided_slice_172[0][
# __________________________________________________________________________________________________
# embedding_173 (Embedding)       (None, 8)            40016       tf_op_layer_strided_slice_173[0][
# __________________________________________________________________________________________________
# embedding_174 (Embedding)       (None, 8)            16944       tf_op_layer_strided_slice_174[0][
# __________________________________________________________________________________________________
# embedding_175 (Embedding)       (None, 8)            32          tf_op_layer_strided_slice_175[0][
# __________________________________________________________________________________________________
# embedding_176 (Embedding)       (None, 8)            15218616    tf_op_layer_strided_slice_176[0][
# __________________________________________________________________________________________________
# embedding_177 (Embedding)       (None, 8)            136         tf_op_layer_strided_slice_177[0][
# __________________________________________________________________________________________________
# embedding_178 (Embedding)       (None, 8)            120         tf_op_layer_strided_slice_178[0][
# __________________________________________________________________________________________________
# embedding_179 (Embedding)       (None, 8)            1086312     tf_op_layer_strided_slice_179[0][
# __________________________________________________________________________________________________
# embedding_180 (Embedding)       (None, 8)            752         tf_op_layer_strided_slice_180[0][
# __________________________________________________________________________________________________
# embedding_181 (Embedding)       (None, 8)            674440      tf_op_layer_strided_slice_181[0][
# __________________________________________________________________________________________________
# embedding_182 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_182[0][
# __________________________________________________________________________________________________
# embedding_183 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_183[0][
# __________________________________________________________________________________________________
# embedding_184 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_184[0][
# __________________________________________________________________________________________________
# embedding_185 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_185[0][
# __________________________________________________________________________________________________
# embedding_186 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_186[0][
# __________________________________________________________________________________________________
# embedding_187 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_187[0][
# __________________________________________________________________________________________________
# embedding_188 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_188[0][
# __________________________________________________________________________________________________
# embedding_189 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_189[0][
# __________________________________________________________________________________________________
# embedding_190 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_190[0][
# __________________________________________________________________________________________________
# embedding_191 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_191[0][
# __________________________________________________________________________________________________
# embedding_192 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_192[0][
# __________________________________________________________________________________________________
# embedding_193 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_193[0][
# __________________________________________________________________________________________________
# embedding_194 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_194[0][
# __________________________________________________________________________________________________
# tf_op_layer_concat_4 (TensorFlo [(None, 312)]        0           embedding_156[0][0]
#                                                                  embedding_157[0][0]
#                                                                  embedding_158[0][0]
#                                                                  embedding_159[0][0]
#                                                                  embedding_160[0][0]
#                                                                  embedding_161[0][0]
#                                                                  embedding_162[0][0]
#                                                                  embedding_163[0][0]
#                                                                  embedding_164[0][0]
#                                                                  embedding_165[0][0]
#                                                                  embedding_166[0][0]
#                                                                  embedding_167[0][0]
#                                                                  embedding_168[0][0]
#                                                                  embedding_169[0][0]
#                                                                  embedding_170[0][0]
#                                                                  embedding_171[0][0]
#                                                                  embedding_172[0][0]
#                                                                  embedding_173[0][0]
#                                                                  embedding_174[0][0]
#                                                                  embedding_175[0][0]
#                                                                  embedding_176[0][0]
#                                                                  embedding_177[0][0]
#                                                                  embedding_178[0][0]
#                                                                  embedding_179[0][0]
#                                                                  embedding_180[0][0]
#                                                                  embedding_181[0][0]
#                                                                  embedding_182[0][0]
#                                                                  embedding_183[0][0]
#                                                                  embedding_184[0][0]
#                                                                  embedding_185[0][0]
#                                                                  embedding_186[0][0]
#                                                                  embedding_187[0][0]
#                                                                  embedding_188[0][0]
#                                                                  embedding_189[0][0]
#                                                                  embedding_190[0][0]
#                                                                  embedding_191[0][0]
#                                                                  embedding_192[0][0]
#                                                                  embedding_193[0][0]
#                                                                  embedding_194[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_4 (TensorFl [(None, 39, 8)]      0           tf_op_layer_concat_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_4 (TensorFlow [(None, 39)]         0           input_5[0][0]
# __________________________________________________________________________________________________
# dnn_4 (DNN)                     (None, 64)           121280      tf_op_layer_concat_4[0][0]
# __________________________________________________________________________________________________
# fm_4 (FM)                       (None, 1)            9248603     tf_op_layer_Reshape_4[0][0]
#                                                                  tf_op_layer_AddV2_4[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 1)            65          dnn_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Add_4 (TensorFlowOp [(None, 1)]          0           fm_4[0][0]
#                                                                  dense_19[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sigmoid_4 (TensorFl [(None, 1)]          0           tf_op_layer_Add_4[0][0]
# ==================================================================================================
# Total params: 83,358,772
# Trainable params: 83,358,772
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, 39)]         0
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_195 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_196 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_197 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_198 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_199 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_200 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_201 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_202 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_203 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_204 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_205 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_206 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_207 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_208 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_209 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_210 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_211 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_212 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_213 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_214 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_215 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_216 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_217 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_218 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_219 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_220 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_221 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_222 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_223 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_224 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_225 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_226 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_227 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_228 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_229 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_230 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_231 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_232 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_233 ( [(None,)]            0           input_6[0][0]
# __________________________________________________________________________________________________
# embedding_195 (Embedding)       (None, 8)            11168       tf_op_layer_strided_slice_195[0][
# __________________________________________________________________________________________________
# embedding_196 (Embedding)       (None, 8)            4424        tf_op_layer_strided_slice_196[0][
# __________________________________________________________________________________________________
# embedding_197 (Embedding)       (None, 8)            20752248    tf_op_layer_strided_slice_197[0][
# __________________________________________________________________________________________________
# embedding_198 (Embedding)       (None, 8)            5587752     tf_op_layer_strided_slice_198[0][
# __________________________________________________________________________________________________
# embedding_199 (Embedding)       (None, 8)            2320        tf_op_layer_strided_slice_199[0][
# __________________________________________________________________________________________________
# embedding_200 (Embedding)       (None, 8)            184         tf_op_layer_strided_slice_200[0][
# __________________________________________________________________________________________________
# embedding_201 (Embedding)       (None, 8)            96384       tf_op_layer_strided_slice_201[0][
# __________________________________________________________________________________________________
# embedding_202 (Embedding)       (None, 8)            4864        tf_op_layer_strided_slice_202[0][
# __________________________________________________________________________________________________
# embedding_203 (Embedding)       (None, 8)            24          tf_op_layer_strided_slice_203[0][
# __________________________________________________________________________________________________
# embedding_204 (Embedding)       (None, 8)            521248      tf_op_layer_strided_slice_204[0][
# __________________________________________________________________________________________________
# embedding_205 (Embedding)       (None, 8)            42472       tf_op_layer_strided_slice_205[0][
# __________________________________________________________________________________________________
# embedding_206 (Embedding)       (None, 8)            17492072    tf_op_layer_strided_slice_206[0][
# __________________________________________________________________________________________________
# embedding_207 (Embedding)       (None, 8)            25024       tf_op_layer_strided_slice_207[0][
# __________________________________________________________________________________________________
# embedding_208 (Embedding)       (None, 8)            208         tf_op_layer_strided_slice_208[0][
# __________________________________________________________________________________________________
# embedding_209 (Embedding)       (None, 8)            102000      tf_op_layer_strided_slice_209[0][
# __________________________________________________________________________________________________
# embedding_210 (Embedding)       (None, 8)            12298584    tf_op_layer_strided_slice_210[0][
# __________________________________________________________________________________________________
# embedding_211 (Embedding)       (None, 8)            80          tf_op_layer_strided_slice_211[0][
# __________________________________________________________________________________________________
# embedding_212 (Embedding)       (None, 8)            40016       tf_op_layer_strided_slice_212[0][
# __________________________________________________________________________________________________
# embedding_213 (Embedding)       (None, 8)            16944       tf_op_layer_strided_slice_213[0][
# __________________________________________________________________________________________________
# embedding_214 (Embedding)       (None, 8)            32          tf_op_layer_strided_slice_214[0][
# __________________________________________________________________________________________________
# embedding_215 (Embedding)       (None, 8)            15218616    tf_op_layer_strided_slice_215[0][
# __________________________________________________________________________________________________
# embedding_216 (Embedding)       (None, 8)            136         tf_op_layer_strided_slice_216[0][
# __________________________________________________________________________________________________
# embedding_217 (Embedding)       (None, 8)            120         tf_op_layer_strided_slice_217[0][
# __________________________________________________________________________________________________
# embedding_218 (Embedding)       (None, 8)            1086312     tf_op_layer_strided_slice_218[0][
# __________________________________________________________________________________________________
# embedding_219 (Embedding)       (None, 8)            752         tf_op_layer_strided_slice_219[0][
# __________________________________________________________________________________________________
# embedding_220 (Embedding)       (None, 8)            674440      tf_op_layer_strided_slice_220[0][
# __________________________________________________________________________________________________
# embedding_221 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_221[0][
# __________________________________________________________________________________________________
# embedding_222 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_222[0][
# __________________________________________________________________________________________________
# embedding_223 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_223[0][
# __________________________________________________________________________________________________
# embedding_224 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_224[0][
# __________________________________________________________________________________________________
# embedding_225 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_225[0][
# __________________________________________________________________________________________________
# embedding_226 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_226[0][
# __________________________________________________________________________________________________
# embedding_227 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_227[0][
# __________________________________________________________________________________________________
# embedding_228 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_228[0][
# __________________________________________________________________________________________________
# embedding_229 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_229[0][
# __________________________________________________________________________________________________
# embedding_230 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_230[0][
# __________________________________________________________________________________________________
# embedding_231 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_231[0][
# __________________________________________________________________________________________________
# embedding_232 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_232[0][
# __________________________________________________________________________________________________
# embedding_233 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_233[0][
# __________________________________________________________________________________________________
# tf_op_layer_concat_5 (TensorFlo [(None, 312)]        0           embedding_195[0][0]
#                                                                  embedding_196[0][0]
#                                                                  embedding_197[0][0]
#                                                                  embedding_198[0][0]
#                                                                  embedding_199[0][0]
#                                                                  embedding_200[0][0]
#                                                                  embedding_201[0][0]
#                                                                  embedding_202[0][0]
#                                                                  embedding_203[0][0]
#                                                                  embedding_204[0][0]
#                                                                  embedding_205[0][0]
#                                                                  embedding_206[0][0]
#                                                                  embedding_207[0][0]
#                                                                  embedding_208[0][0]
#                                                                  embedding_209[0][0]
#                                                                  embedding_210[0][0]
#                                                                  embedding_211[0][0]
#                                                                  embedding_212[0][0]
#                                                                  embedding_213[0][0]
#                                                                  embedding_214[0][0]
#                                                                  embedding_215[0][0]
#                                                                  embedding_216[0][0]
#                                                                  embedding_217[0][0]
#                                                                  embedding_218[0][0]
#                                                                  embedding_219[0][0]
#                                                                  embedding_220[0][0]
#                                                                  embedding_221[0][0]
#                                                                  embedding_222[0][0]
#                                                                  embedding_223[0][0]
#                                                                  embedding_224[0][0]
#                                                                  embedding_225[0][0]
#                                                                  embedding_226[0][0]
#                                                                  embedding_227[0][0]
#                                                                  embedding_228[0][0]
#                                                                  embedding_229[0][0]
#                                                                  embedding_230[0][0]
#                                                                  embedding_231[0][0]
#                                                                  embedding_232[0][0]
#                                                                  embedding_233[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_5 (TensorFl [(None, 39, 8)]      0           tf_op_layer_concat_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_5 (TensorFlow [(None, 39)]         0           input_6[0][0]
# __________________________________________________________________________________________________
# dnn_5 (DNN)                     (None, 64)           121280      tf_op_layer_concat_5[0][0]
# __________________________________________________________________________________________________
# fm_5 (FM)                       (None, 1)            9248603     tf_op_layer_Reshape_5[0][0]
#                                                                  tf_op_layer_AddV2_5[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 1)            65          dnn_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Add_5 (TensorFlowOp [(None, 1)]          0           fm_5[0][0]
#                                                                  dense_23[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sigmoid_5 (TensorFl [(None, 1)]          0           tf_op_layer_Add_5[0][0]
# ==================================================================================================
# Total params: 83,358,772
# Trainable params: 83,358,772
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 39)]         0
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_234 ( [(None,)]            0           input_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_235 ( [(None,)]            0           input_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_236 ( [(None,)]            0           input_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_237 ( [(None,)]            0           input_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_238 ( [(None,)]            0           input_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_239 ( [(None,)]            0           input_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_240 ( [(None,)]            0           input_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_241 ( [(None,)]            0           input_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_242 ( [(None,)]            0           input_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_243 ( [(None,)]            0           input_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_244 ( [(None,)]            0           input_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_245 ( [(None,)]            0           input_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_246 ( [(None,)]            0           input_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_247 ( [(None,)]            0           input_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_248 ( [(None,)]            0           input_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_249 ( [(None,)]            0           input_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_250 ( [(None,)]            0           input_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_251 ( [(None,)]            0           input_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_252 ( [(None,)]            0           input_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_253 ( [(None,)]            0           input_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_254 ( [(None,)]            0           input_7[0][0]
# ...
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_262 ( [(None,)]            0           input_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_263 ( [(None,)]            0           input_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_264 ( [(None,)]            0           input_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_265 ( [(None,)]            0           input_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_266 ( [(None,)]            0           input_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_267 ( [(None,)]            0           input_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_268 ( [(None,)]            0           input_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_269 ( [(None,)]            0           input_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_270 ( [(None,)]            0           input_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_271 ( [(None,)]            0           input_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_272 ( [(None,)]            0           input_7[0][0]
# __________________________________________________________________________________________________
# embedding_234 (Embedding)       (None, 8)            11168       tf_op_layer_strided_slice_234[0][
# __________________________________________________________________________________________________
# embedding_235 (Embedding)       (None, 8)            4424        tf_op_layer_strided_slice_235[0][
# __________________________________________________________________________________________________
# embedding_236 (Embedding)       (None, 8)            20752248    tf_op_layer_strided_slice_236[0][
# __________________________________________________________________________________________________
# embedding_237 (Embedding)       (None, 8)            5587752     tf_op_layer_strided_slice_237[0][
# __________________________________________________________________________________________________
# embedding_238 (Embedding)       (None, 8)            2320        tf_op_layer_strided_slice_238[0][
# __________________________________________________________________________________________________
# embedding_239 (Embedding)       (None, 8)            184         tf_op_layer_strided_slice_239[0][
# __________________________________________________________________________________________________
# embedding_240 (Embedding)       (None, 8)            96384       tf_op_layer_strided_slice_240[0][
# __________________________________________________________________________________________________
# embedding_241 (Embedding)       (None, 8)            4864        tf_op_layer_strided_slice_241[0][
# __________________________________________________________________________________________________
# embedding_242 (Embedding)       (None, 8)            24          tf_op_layer_strided_slice_242[0][
# __________________________________________________________________________________________________
# embedding_243 (Embedding)       (None, 8)            521248      tf_op_layer_strided_slice_243[0][
# __________________________________________________________________________________________________
# embedding_244 (Embedding)       (None, 8)            42472       tf_op_layer_strided_slice_244[0][
# __________________________________________________________________________________________________
# embedding_245 (Embedding)       (None, 8)            17492072    tf_op_layer_strided_slice_245[0][
# __________________________________________________________________________________________________
# embedding_246 (Embedding)       (None, 8)            25024       tf_op_layer_strided_slice_246[0][
# __________________________________________________________________________________________________
# embedding_247 (Embedding)       (None, 8)            208         tf_op_layer_strided_slice_247[0][
# __________________________________________________________________________________________________
# embedding_248 (Embedding)       (None, 8)            102000      tf_op_layer_strided_slice_248[0][
# __________________________________________________________________________________________________
# embedding_249 (Embedding)       (None, 8)            12298584    tf_op_layer_strided_slice_249[0][
# __________________________________________________________________________________________________
# embedding_250 (Embedding)       (None, 8)            80          tf_op_layer_strided_slice_250[0][
# __________________________________________________________________________________________________
# embedding_251 (Embedding)       (None, 8)            40016       tf_op_layer_strided_slice_251[0][
# __________________________________________________________________________________________________
# embedding_252 (Embedding)       (None, 8)            16944       tf_op_layer_strided_slice_252[0][
# __________________________________________________________________________________________________
# embedding_253 (Embedding)       (None, 8)            32          tf_op_layer_strided_slice_253[0][
# __________________________________________________________________________________________________
# embedding_254 (Embedding)       (None, 8)            15218616    tf_op_layer_strided_slice_254[0][
# __________________________________________________________________________________________________
# embedding_255 (Embedding)       (None, 8)            136         tf_op_layer_strided_slice_255[0][
# __________________________________________________________________________________________________
# embedding_256 (Embedding)       (None, 8)            120         tf_op_layer_strided_slice_256[0][
# __________________________________________________________________________________________________
# embedding_257 (Embedding)       (None, 8)            1086312     tf_op_layer_strided_slice_257[0][
# __________________________________________________________________________________________________
# embedding_258 (Embedding)       (None, 8)            752         tf_op_layer_strided_slice_258[0][
# __________________________________________________________________________________________________
# embedding_259 (Embedding)       (None, 8)            674440      tf_op_layer_strided_slice_259[0][
# __________________________________________________________________________________________________
# embedding_260 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_260[0][
# __________________________________________________________________________________________________
# embedding_261 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_261[0][
# __________________________________________________________________________________________________
# embedding_262 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_262[0][
# __________________________________________________________________________________________________
# embedding_263 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_263[0][
# __________________________________________________________________________________________________
# embedding_264 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_264[0][
# __________________________________________________________________________________________________
# embedding_265 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_265[0][
# __________________________________________________________________________________________________
# embedding_266 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_266[0][
# __________________________________________________________________________________________________
# embedding_267 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_267[0][
# __________________________________________________________________________________________________
# embedding_268 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_268[0][
# __________________________________________________________________________________________________
# embedding_269 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_269[0][
# __________________________________________________________________________________________________
# embedding_270 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_270[0][
# __________________________________________________________________________________________________
# embedding_271 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_271[0][
# __________________________________________________________________________________________________
# embedding_272 (Embedding)       (None, 8)            800         tf_op_layer_strided_slice_272[0][
# __________________________________________________________________________________________________
# tf_op_layer_concat_6 (TensorFlo [(None, 312)]        0           embedding_234[0][0]
#                                                                  embedding_235[0][0]
#                                                                  embedding_236[0][0]
#                                                                  embedding_237[0][0]
#                                                                  embedding_238[0][0]
#                                                                  embedding_239[0][0]
#                                                                  embedding_240[0][0]
#                                                                  embedding_241[0][0]
#                                                                  embedding_242[0][0]
#                                                                  embedding_243[0][0]
#                                                                  embedding_244[0][0]
#                                                                  embedding_245[0][0]
#                                                                  embedding_246[0][0]
#                                                                  embedding_247[0][0]
#                                                                  embedding_248[0][0]
#                                                                  embedding_249[0][0]
#                                                                  embedding_250[0][0]
#                                                                  embedding_251[0][0]
#                                                                  embedding_252[0][0]
#                                                                  embedding_253[0][0]
#                                                                  embedding_254[0][0]
#                                                                  embedding_255[0][0]
#                                                                  embedding_256[0][0]
#                                                                  embedding_257[0][0]
#                                                                  embedding_258[0][0]
#                                                                  embedding_259[0][0]
#                                                                  embedding_260[0][0]
#                                                                  embedding_261[0][0]
#                                                                  embedding_262[0][0]
#                                                                  embedding_263[0][0]
#                                                                  embedding_264[0][0]
#                                                                  embedding_265[0][0]
#                                                                  embedding_266[0][0]
#                                                                  embedding_267[0][0]
#                                                                  embedding_268[0][0]
#                                                                  embedding_269[0][0]
#                                                                  embedding_270[0][0]
#                                                                  embedding_271[0][0]
#                                                                  embedding_272[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Reshape_6 (TensorFl [(None, 39, 8)]      0           tf_op_layer_concat_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_6 (TensorFlow [(None, 39)]         0           input_7[0][0]
# __________________________________________________________________________________________________
# dnn_6 (DNN)                     (None, 64)           121280      tf_op_layer_concat_6[0][0]
# __________________________________________________________________________________________________
# fm_6 (FM)                       (None, 1)            9248603     tf_op_layer_Reshape_6[0][0]
#                                                                  tf_op_layer_AddV2_6[0][0]
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 1)            65          dnn_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Add_6 (TensorFlowOp [(None, 1)]          0           fm_6[0][0]
#                                                                  dense_27[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sigmoid_6 (TensorFl [(None, 1)]          0           tf_op_layer_Add_6[0][0]
# ==================================================================================================
# Total params: 83,358,772
# Trainable params: 83,358,772
# Non-trainable params: 0
# __________________________________________________________________________________________________
#
# 438/438 [==============================] - 39s 89ms/step - loss: 0.5124 - auc_4: 0.7759
#
# 51/51 [==============================] - 5s 90ms/step - loss: 0.3458 - auc_5: 0.7784
#
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3092 - auc_6: 0.7628
