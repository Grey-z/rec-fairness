# %%
import pandas
import pandas as pd
import numpy as np
import sys
from sklearn.metrics import log_loss, roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.python.keras.preprocessing.sequence import pad_sequences
import tensorflow as tf
from tqdm import tqdm

deepctr_path = '/root/linghui/rec-fairness/'
sys.path.append(deepctr_path)
import deepctr
from deepctr.models import DeepFM
from deepctr.feature_column import SparseFeat, VarLenSparseFeat, get_feature_names
# from utilis import get_feat_dict

# %%
def get_feat_dict(data):
    if data == 'ml-1m':
        feat_dict = {'movie_id': 3706,
                 'user_id': 6040,
                 'gender': 2,
                 'age': 7,
                 'occupation': 21,
                 'zipcode': 3439}
    return feat_dict

# %%
saved_model_path = '/data/linghui/saved_model/deepfm-ml-1m/'

saved_data_path = '/data/linghui/ml-1m/processed_data/'
train_data_path = saved_data_path + 'train_data.csv' 
test_data_path = saved_data_path + 'test_data.csv'

#load data
train_data = pd.read_csv(train_data_path,index_col=0)
# Out:
# /opt/conda/lib/python3.8/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
train_data
# Out:
#          user_id  movie_id  rating   timestamp  \
# 550763      2658        96       1  1042575453
# 645964      3208        77       1   965806436
# 570742      2781       502       1   966997407
# 1256036      622        93       0           0
# 655568      3276      2003       1   965682094
# ...          ...       ...     ...         ...
# 950341      5272       426       1   960857360
# 1999038     5597       248       0           0
# 307016       928         0       1   974730227
# 970345      5387      3644       1   957783320
# 1901924     4947      1453       0           0
#
#                                                 title               genres  \
# 550763                              Doors, The (1991)   [1, 4, 0, 0, 0, 0]
# 645964   Willy Wonka and the Chocolate Factory (1971)   [8, 3, 6, 9, 0, 0]
# 570742                               Apollo 13 (1995)   [1, 0, 0, 0, 0, 0]
# 1256036                                Platoon (1986)  [1, 11, 0, 0, 0, 0]
# 655568                   Palm Beach Story, The (1942)   [6, 0, 0, 0, 0, 0]
# ...                                               ...                  ...
# 950341                               Walkabout (1971)   [1, 0, 0, 0, 0, 0]
# 1999038               Nikita (La Femme Nikita) (1990)  [12, 0, 0, 0, 0, 0]
# 307016                               Toy Story (1995)   [2, 3, 6, 0, 0, 0]
# 970345           Adventures of Robin Hood, The (1938)   [7, 8, 0, 0, 0, 0]
# 1901924                  Theory of Flight, The (1998)   [6, 1, 5, 0, 0, 0]
#
#          gender  age  occupation  zipcode
# 550763        1    1          15     1612
# 645964        1    1          15     2561
# 570742        0    3          18     1091
# 1256036       1    3          19      408
# 655568        0    4           4     2104
# ...         ...  ...         ...      ...
# 950341        0    2          15     2202
# 1999038       0    2           7     1152
# 307016        1    3          16      459
# 970345        1    5          13      778
# 1901924       0    2           1     3360
#
# [1600334 rows x 10 columns]

# %%
dataset = 'ml-1m'
feat_dict = get_feat_dict(dataset)
feat_dict
# Out:
# {'movie_id': 3706,
#  'user_id': 6040,
#  'gender': 2,
#  'age': 7,
#  'occupation': 21,
#  'zipcode': 3439}

# %%
sparse_features = ["movie_id", "user_id",
                   "gender", "age", "occupation", "zipcode", ]

fixlen_feature_columns = [SparseFeat(feat, feat_dict[feat], embedding_dim=4)
								  for feat in sparse_features]

# %%
movie_size = 18
max_len = 6

use_weighted_sequence = False
if use_weighted_sequence:
    varlen_feature_columns = [VarLenSparseFeat(SparseFeat('genres', vocabulary_size = movie_size + 1, 
                                                          embedding_dim=4), maxlen=max_len, combiner='mean', weight_name='genres_weight')]  
    # Notice : value 0 is for padding for sequence input feature
else:
    varlen_feature_columns = [VarLenSparseFeat(SparseFeat('genres', vocabulary_size = movie_size + 1, 
                                                          embedding_dim=4), maxlen=max_len, combiner='mean', weight_name=None)]  
    # Notice : value 0 is for padding for sequence input feature

linear_feature_columns = fixlen_feature_columns + varlen_feature_columns
dnn_feature_columns = fixlen_feature_columns + varlen_feature_columns

feature_names = get_feature_names(linear_feature_columns + dnn_feature_columns)

# %%
train_model_input = {name: train_data[name].values for name in feature_names}
label = train_data['rating'].values

# %%
train_model_input
# Out:
# {'movie_id': array([  96,   77,  502, ...,    0, 3644, 1453]),
#  'user_id': array([2658, 3208, 2781, ...,  928, 5387, 4947]),
#  'gender': array([1, 1, 0, ..., 1, 1, 0]),
#  'age': array([1, 1, 3, ..., 3, 5, 2]),
#  'occupation': array([15, 15, 18, ..., 16, 13,  1]),
#  'zipcode': array([1612, 2561, 1091, ...,  459,  778, 3360]),
#  'genres': array(['[1, 4, 0, 0, 0, 0]', '[8, 3, 6, 9, 0, 0]', '[1, 0, 0, 0, 0, 0]',
#         ..., '[2, 3, 6, 0, 0, 0]', '[7, 8, 0, 0, 0, 0]',
#         '[6, 1, 5, 0, 0, 0]'], dtype=object)}

# %%
label
# Out:
# array([1, 1, 1, ..., 1, 1, 0])

# %%
model = DeepFM(linear_feature_columns, dnn_feature_columns, task='binary')
# Out:
# 2022-05-23 15:31:10.508235: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2022-05-23 15:31:10.523429: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:08:00.0 name: NVIDIA GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.62GHz coreCount: 28 deviceMemorySize: 10.92GiB deviceMemoryBandwidth: 451.17GiB/s
# 2022-05-23 15:31:10.524968: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 1 with properties:
# pciBusID: 0000:09:00.0 name: NVIDIA GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.62GHz coreCount: 28 deviceMemorySize: 10.92GiB deviceMemoryBandwidth: 451.17GiB/s
# 2022-05-23 15:31:10.525004: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2022-05-23 15:31:10.539238: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2022-05-23 15:31:10.547790: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2022-05-23 15:31:10.549658: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2022-05-23 15:31:10.564559: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2022-05-23 15:31:10.566734: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2022-05-23 15:31:10.592044: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2022-05-23 15:31:10.598233: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0, 1
# 2022-05-23 15:31:10.598613: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-23 15:31:10.612108: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2499890000 Hz
# 2022-05-23 15:31:10.615695: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55ff9d8c5ea0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-05-23 15:31:10.615719: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-05-23 15:31:10.935469: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55ff9d9328c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2022-05-23 15:31:10.935523: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce GTX 1080 Ti, Compute Capability 6.1
# 2022-05-23 15:31:10.935531: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (1): NVIDIA GeForce GTX 1080 Ti, Compute Capability 6.1
# 2022-05-23 15:31:10.938628: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:08:00.0 name: NVIDIA GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.62GHz coreCount: 28 deviceMemorySize: 10.92GiB deviceMemoryBandwidth: 451.17GiB/s
# 2022-05-23 15:31:10.940550: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 1 with properties:
# pciBusID: 0000:09:00.0 name: NVIDIA GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.62GHz coreCount: 28 deviceMemorySize: 10.92GiB deviceMemoryBandwidth: 451.17GiB/s
# 2022-05-23 15:31:10.940608: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2022-05-23 15:31:10.940642: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2022-05-23 15:31:10.940664: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2022-05-23 15:31:10.940685: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2022-05-23 15:31:10.940706: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2022-05-23 15:31:10.940727: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2022-05-23 15:31:10.940748: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2022-05-23 15:31:10.945567: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0, 1
# 2022-05-23 15:31:10.945791: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2022-05-23 15:31:12.062222: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-05-23 15:31:12.062275: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0 1
# 2022-05-23 15:31:12.062284: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N Y
# 2022-05-23 15:31:12.062289: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 1:   Y N
# 2022-05-23 15:31:12.066764: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10273 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:08:00.0, compute capability: 6.1)
# 2022-05-23 15:31:12.069138: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 10273 MB memory) -> physical GPU (device: 1, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:09:00.0, compute capability: 6.1)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(), loss='binary_crossentropy',
              metrics=['AUC', 'Precision', 'Recall'])
model.summary()

print('begain training')
model.fit(train_model_input, label,
						batch_size=256, epochs=20, verbose=2,
						validation_split=0.2)
